# %% [markdown]
# ## Games - categories

# %%
import pandas as pd
import json

# %%
games_df = pd.read_csv(r'C:\Users\gross\OneDrive\Desktop\Games_dataset.csv', sep = ',').set_index('ID_game')
list1 = games_df['game_name'].to_list()

# %%
with open(r'C:\Users\gross\OneDrive\Desktop\games.json', encoding="utf8") as f:
    games = json.load(f)
#games

# %%
games['906850']
# Out:
# {'name': 'Again?',
#  'release_date': {'coming_soon': False, 'date': 'Aug 8, 2018'},
#  'required_age': 0,
#  'is_free': False,
#  'price': '$0.49',
#  'detailed_description': "Again? is easy game for relax with quiet music. You don't need to worry about achievements, about competition with other players.<br />\r\nThe principle of the game: before you square field 4x4, it randomly appear cubes with the number &quot;2&quot;,by clicking on the arrows to move the cubes together trying to connect the same numbers. Your mission is to get a higher number. But beware, if the field is full, you have to start AGAIN!?<br />\r\nFeatures:<br />\r\n- minimum disk space and easy installation;<br />\r\n- the easiest gameplay;<br />\r\n- wonderful music;<br />\r\n- ideal, who want to kill 5-10 minutes, without dipping into the game.<br />\r\nJust start and play!",
# ...

# %%
games['906850'].keys()
# Out:
# dict_keys(['name', 'release_date', 'required_age', 'is_free', 'price', 'detailed_description', 'about_the_game', 'short_description', 'supported_languages', 'header_image', 'website', 'windows', 'mac', 'linux', 'achievements', 'developers', 'publishers', 'categories', 'genres', 'screenshots', 'movies'])

# %%
list2 = []
for keys in games:
    x = games[keys]['name']
    list2.insert(0, x)
# list2.strip()
# list2

# %%
list2
# Out:
# ['JUMPGRID',
#  '2048',
#  'Marvelous Designer 8 for Steam',
#  'Grimm & Tonic: Aperitif',
#  'The 3rd Building 三教',
#  'The Hot Dog would Explode',
#  'Temporality',
#  "An Adventurer's Tale",
#  'Two Till Midnight',
#  'Thrusty Ship',
#  'Scamp: High Hat Havoc',
#  'Double Bubble Blaster Madness VR',
#  'Criminal Pursuit Force',
#  'Death Cave',
#  'Captain ToonHead vs the Punks from Outer Space',
#  'Offside',
#  'Achievement Collector: Space',
#  'Blocky Snake',
#  '✌ Johnny Rocket',
#  'Inside Grass',
#  'NIGHT FALLEN',
#  'Rapid Fire',
#  'Girls in Glasses',
#  'Unheard',
#  '枕边少女 MOE Hypnotist - share dreams with you',
#  "Goblin's Shop",
#  'Lolly Pang VR',
#  'I Walk Among Zombies Vol. 1 (Adult Version)',
#  'Hard Work',
#  'Fractal To Desktop',
#  'Burnout Drift',
#  'Istanbul: Digital Edition',
#  'Pan Panda',
#  'Timberman VS',
#  'ManGuin – Penguin Apocalypse',
#  'Zombie school-丧尸学院',
#  'Stranded Sails - Explorers of the Cursed Islands',
#  'Thrill Rollercoasters',
# ...

# %%
set2 = set(list2)
len(set2)
# Out:
# 54593

# %%
set1 = set(list1)
len(set1)
# Out:
# 1145

# %%
intersection = set1.intersection(list2)
intersection
# Out:
# {'2Dark',
#  '60 Seconds!',
#  '7 Days to Die',
#  'A Girls Fabric Face',
#  'A Memoir Blue',
#  'A Plague Tale: Innocence',
#  'A Way Out',
#  'AI Battle Royale Generator',
#  'ALTF4',
#  'Alice: Madness Returns',
#  'Alien: Isolation',
#  'Amnesia: A Machine for Pigs',
#  'Amnesia: Rebirth',
#  'Amnesia: The Dark Descent',
#  'Armello',
#  'Assetto Corsa',
#  'Atomicrops',
#  'Automobilista 2',
#  'Aztech Forgotten Gods',
#  'BUS SIMULATOR',
#  'Bakery Simulator',
#  'Batman: Arkham City',
#  'Battlefield V',
#  'Battlefleet Gothic: Armada 2',
#  'Beholder',
#  'Ben and Ed - Blood Party',
#  'Bendy and the Ink Machine',
#  'Beyond: Two Souls',
#  'Blair Witch',
#  'Blasphemous',
#  'BlazBlue: Cross Tag Battle',
#  'Blood and Bacon',
#  'BloodRayne 2: Terminal Cut',
#  'Bloodstained: Ritual of the Night',
#  'Bonbon',
#  'Bully: Scholarship Edition',
#  'Car Mechanic Simulator 2018',
#  'Cat Quest',
#  'Celeste',
#  'Chaos on Deponia',
#  'Chess',
#  'Choice Chamber',
# ...

# %%
len(intersection)
# Out:
# 332
