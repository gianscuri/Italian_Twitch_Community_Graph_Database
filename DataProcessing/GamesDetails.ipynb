# %% [markdown]
# # Games - categories

# %%
import pandas as pd
import json
import re
import numpy as np

# %% [markdown]
# importo games_dataset di twitch:

# %%
games_tw = pd.read_csv('https://raw.githubusercontent.com/gianscuri/Twitch_Community_Graph/main/DataProcessing/Games_dataset.csv', sep = ',')
len(games_tw)
# Out:
# 1144

# %% [markdown]
# Creo dizionario : \
#     {'ID_game' : { \
#         'twitch_name': ' ', \
#          'steam_name' : ' ', \
#          'match_score': ' '\
#           'twitch_clean': ' ', \
#          'steam_clean' : ' ', \
#          }

# %%
match_dict = {}

for i in range(len(games_tw)):
    match_dict[i] = {}
    match_dict[i]['twitch_name'] = games_tw.game_name[i]
    match_dict[i]['steam_name'] = ''
    match_dict[i]['match_score'] = ''
    match_dict[i]['twitch_clean'] = re.sub(r"[^a-zA-Z0-9 ']",'',match_dict[i]['twitch_name']).lower().strip()
    match_dict[i]['steam_clean'] = ''
match_dict
# Out:
# {0: {'twitch_name': 'Monster Hunter Generations Ultimate',
#   'steam_name': '',
#   'match_score': '',
#   'twitch_clean': 'monster hunter generations ultimate',
#   'steam_clean': ''},
#  1: {'twitch_name': 'Alice: Madness Returns',
#   'steam_name': '',
#   'match_score': '',
#   'twitch_clean': 'alice madness returns',
#   'steam_clean': ''},
#  2: {'twitch_name': 'Hold Fast',
#   'steam_name': '',
#   'match_score': '',
#   'twitch_clean': 'hold fast',
#   'steam_clean': ''},
#  3: {'twitch_name': 'Pokémon Trading Card Game Online',
#   'steam_name': '',
#   'match_score': '',
#   'twitch_clean': 'pokmon trading card game online',
#   'steam_clean': ''},
#  4: {'twitch_name': 'Witch It',
#   'steam_name': '',
#   'match_score': '',
#   'twitch_clean': 'witch it',
#   'steam_clean': ''},
#  5: {'twitch_name': "Dante's Inferno",
#   'steam_name': '',
#   'match_score': '',
#   'twitch_clean': "dante's inferno",
#   'steam_clean': ''},
# ...

# %%
with open(r'C:\Users\gross\OneDrive\Desktop\games.json', encoding="utf8") as f:
    games = json.load(f)
#games

# %%
games['906850']
# Out:
# {'name': 'Again?',
#  'release_date': {'coming_soon': False, 'date': 'Aug 8, 2018'},
#  'required_age': 0,
#  'is_free': False,
#  'price': '$0.49',
#  'detailed_description': "Again? is easy game for relax with quiet music. You don't need to worry about achievements, about competition with other players.<br />\r\nThe principle of the game: before you square field 4x4, it randomly appear cubes with the number &quot;2&quot;,by clicking on the arrows to move the cubes together trying to connect the same numbers. Your mission is to get a higher number. But beware, if the field is full, you have to start AGAIN!?<br />\r\nFeatures:<br />\r\n- minimum disk space and easy installation;<br />\r\n- the easiest gameplay;<br />\r\n- wonderful music;<br />\r\n- ideal, who want to kill 5-10 minutes, without dipping into the game.<br />\r\nJust start and play!",
# ...

# %% [markdown]
# lista giochi di steam:

# %%
steam_games = []
for keys in games:
    x = games[keys]['name']
    steam_games.append(x)
len(steam_games)
# Out:
# 54946

# %%
len(set(steam_games))
# Out:
# 54593

# %% [markdown]
# Ci sono 353 nomi duplicati nel json steam_games!!!
# per ora rimuovo. Dovrei vedere se i dettagli associati al gioco cambiano

# %%
steam_games = list(set(steam_games))
#emoticons + chinese

# %% [markdown]
# Ricavo lista elementi comuni = con match perfetto.

# %%
len(list(set(games_tw.game_name) & set(steam_games)))
# Out:
# 332

# %% [markdown]
# Nel match_dict aggiorno con steam_name e match_score = 100 (come percentuale).

# %%
for i in range(len(match_dict)):
    if match_dict[i]['twitch_name'] in steam_games:
        match_dict[i]['steam_name'] = match_dict[i]['twitch_name']
        match_dict[i]['match_score'] = '100'
    else:
        pass
match_dict
# Out:
# {0: {'twitch_name': 'Monster Hunter Generations Ultimate',
#   'steam_name': '',
#   'match_score': '',
#   'twitch_clean': 'monster hunter generations ultimate',
#   'steam_clean': ''},
#  1: {'twitch_name': 'Alice: Madness Returns',
#   'steam_name': 'Alice: Madness Returns',
#   'match_score': '100',
#   'twitch_clean': 'alice madness returns',
#   'steam_clean': ''},
#  2: {'twitch_name': 'Hold Fast',
#   'steam_name': '',
#   'match_score': '',
#   'twitch_clean': 'hold fast',
#   'steam_clean': ''},
#  3: {'twitch_name': 'Pokémon Trading Card Game Online',
#   'steam_name': '',
#   'match_score': '',
#   'twitch_clean': 'pokmon trading card game online',
#   'steam_clean': ''},
#  4: {'twitch_name': 'Witch It',
#   'steam_name': 'Witch It',
#   'match_score': '100',
#   'twitch_clean': 'witch it',
#   'steam_clean': ''},
#  5: {'twitch_name': "Dante's Inferno",
#   'steam_name': '',
#   'match_score': '',
#   'twitch_clean': "dante's inferno",
#   'steam_clean': ''},
# ...

# %%
match_df = pd.DataFrame.from_dict(match_dict,orient='index')
match_df
# Out:
#                               twitch_name                         steam_name  \
# 0     Monster Hunter Generations Ultimate
# 1                  Alice: Madness Returns             Alice: Madness Returns
# 2                               Hold Fast
# 3        Pokémon Trading Card Game Online
# 4                                Witch It                           Witch It
# ...                                   ...                                ...
# 1139    Rise of Nations: Extended Edition  Rise of Nations: Extended Edition
# 1140        Paper Mario: The Origami King
# 1141     The Inheritance of Crimson Manor
# 1142                               Occult
# 1143                      Sign of Silence                    Sign of Silence
#
#      match_score                         twitch_clean steam_clean
# 0                 monster hunter generations ultimate
# 1            100                alice madness returns
# 2                                           hold fast
# ...

# %%
#per risalire alle info nel json dalla stringa 'steam_name'

# for key in games:
#     if games[key]['name'] == 'steam_name':
#         print(games[key])

# %% [markdown]
# ## STEP 1 - cleaning & rematch

# %% [markdown]
# prima di usare fuzzy faccio cleaning su stringhe non ancora matchate:
# - lower
# - strip
# - remove emoticons/chinese/japanese/korean characters
#
# faccio rematch

# %%
# l'unica stringa con carattere cinese o simile è già stata matchata

# for i in range(len(games_tw.game_name)):
#     print(i, re.findall(r'[\u4e00-\u9fff]+',games_tw.game_name[i]))
    
# match_df.loc[346]

# %%
#cleaning twitch_name
# j=0
# for elem in match_df.steam_name:
#     if elem == '':
#         match_df.twitch_clean[j] = re.sub(r"[^a-zA-Z0-9 ']",'',match_df.twitch_name[j]).lower().strip()
#     else:
#         match_df.twitch_clean[j] = ''
#     j+=1

# %% [markdown]
# cleaning della lista steam_games e trasformo in df (associo nome originale a pulito)

# %%
steam_df = pd.DataFrame()
steam_df['steam_name'] = steam_games

steam_clean = []
for string in steam_games:
    new_string = re.sub(r"[^a-zA-Z0-9 ']",'',string).lower().strip()
    steam_clean.append(new_string)
steam_df['steam_clean'] = steam_clean
steam_df = steam_df[1:].reset_index(drop=True)   #rimuovo prima riga vuota

# %%
steam_df.head()
# Out:
#                      steam_name                   steam_clean
# 0                    Descending                    descending
# 1             Dungeon Adventure             dungeon adventure
# 2  Artifact Adventure Gaiden DX  artifact adventure gaiden dx
# 3  Slide Stories: Bucky's Quest   slide stories bucky's quest
# 4                    Fatal Core                    fatal core

# %%
steam_df[steam_df.steam_clean == '']
# Out:
#                                     steam_name steam_clean
# 44                                       江湖侠客行
# 50                                      小怪物必须死
# 117                                         八尾
# 133                                       猜拳为尊
# 181                                      招募与冒险
# 213                                      看不见的爱
# 272                                      溜冰的猪少
# 374                              그랑 엠파이어 : 아마네
# 485                                       什么找茬
# 510                                      去死吧蝙蝠
# 602                                   マグネクション磁
# 768                               《鬼畜战记：金坷垃传说》
# 856                                       问道仙途
# 902                               恋爱绮谭~不存在的夏天~
# 982                             ガリア戦記　雄篇アンナーレス
# 1073                                  アルカナリッター
# 1330                                      ドトコイ
# 1499                                     恐龙大冒险
# 1505                                      伊始之战
# ...

# %% [markdown]
# rimuovo queste righe cinesi dal dataframe steam_df

# %%
steam_df = steam_df[steam_df.steam_clean != '']
len(steam_df)
# Out:
# 53986

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
match_df
# Out:
#                                             twitch_name  \
# 0                   Monster Hunter Generations Ultimate
# 1                                Alice: Madness Returns
# 2                                             Hold Fast
# 3                      Pokémon Trading Card Game Online
# 4                                              Witch It
# 5                                       Dante's Inferno
# 6                     The Stanley Parable: Ultra Deluxe
# 7                                        The Long Drive
# 8                                          Cyber Hunter
# 9                                           Rogue Lords
# 10                      Assassin's Creed IV: Black Flag
# 11                                               INSIDE
# 12                          DRAGON BALL Z DOKKAN BATTLE
# 13                                                 V696
# 14                                                Hades
# 15                                        Stranded Deep
# ...

# %% [markdown]
# ricavo set elementi comuni con match perfetto tra liste pulite

# %%
len(list(set(match_df.twitch_clean) & set(steam_clean)))
# Out:
# 412

# %%
for i in range(len(match_df)):
    if ((match_df.match_score[i] != '100') and (match_df.twitch_clean[i] in list(set(steam_clean)))):
        match_df.steam_clean[i] = match_df.twitch_clean[i]
        match_df.match_score[i] = '100'
    else:
        pass
match_df
# Out:
#                                             twitch_name  \
# 0                   Monster Hunter Generations Ultimate
# 1                                Alice: Madness Returns
# 2                                             Hold Fast
# 3                      Pokémon Trading Card Game Online
# 4                                              Witch It
# 5                                       Dante's Inferno
# 6                     The Stanley Parable: Ultra Deluxe
# 7                                        The Long Drive
# 8                                          Cyber Hunter
# 9                                           Rogue Lords
# 10                      Assassin's Creed IV: Black Flag
# 11                                               INSIDE
# 12                          DRAGON BALL Z DOKKAN BATTLE
# 13                                                 V696
# 14                                                Hades
# 15                                        Stranded Deep
# ...

# %%
match_df[match_df.steam_clean != ''].count()
# Out:
# twitch_name     80
# steam_name      80
# match_score     80
# twitch_clean    80
# steam_clean     80
# dtype: int64

# %% [markdown]
# 80 nuovi elementi matchati -> inserisco in dataframe con 100%

# %%
len(steam_df.steam_clean) - len(set(steam_df.steam_clean))
# Out:
# 273

# %% [markdown]
# ci sono 273 duplicati in lista steam_clean --> elimino

# %%
steam_df = steam_df.drop_duplicates(subset=['steam_clean'], keep='first').reset_index(drop=True)
len(steam_df)
# Out:
# 53713

# %%
steam_df.head()
# Out:
#                      steam_name                   steam_clean
# 0                    Descending                    descending
# 1             Dungeon Adventure             dungeon adventure
# 2  Artifact Adventure Gaiden DX  artifact adventure gaiden dx
# 3  Slide Stories: Bucky's Quest   slide stories bucky's quest
# 4                    Fatal Core                    fatal core

# %%
############# COSA ETERNA!!!!

# %%
contatore = 0
for i in range(len(match_df)):
    for j in range(len(steam_df)):
        if match_df.steam_clean[i]  == steam_df.steam_clean[j]:
            match_df.steam_name[i] = steam_df.steam_name[j]   
    contatore += 1
    print(f"sono alla {contatore} richiesta", end ="\r")
# Out:
# sono alla 1144 richiesta

# %%
#match_df.to_csv('match_df.csv')

# %% [markdown]
# ###### salvato df match perfetti

# %%
match_df[match_df.match_score == '100'].to_csv('match_100.csv')

# %%
match_df[match_df.match_score != '100'].to_csv('non_match.csv')

# %%
fuzzy_match = pd.read_csv('C:\\Users\\gross\\OneDrive\\Documenti\\GitHub\\Twitch_Community_Graph\\DataProcessing\\non_match.csv',sep=',')
fuzzy_match = fuzzy_match.replace(np.nan, '', regex=True).drop(['Unnamed: 0'],axis=1)
fuzzy_match
# Out:
#                                            twitch_name steam_name match_score  \
# 0                  Monster Hunter Generations Ultimate
# 1                                            Hold Fast
# 2                     Pokémon Trading Card Game Online
# 3                                      Dante's Inferno
# 4                    The Stanley Parable: Ultra Deluxe
# 5                                       The Long Drive
# 6                      Assassin's Creed IV: Black Flag
# 7                          DRAGON BALL Z DOKKAN BATTLE
# 8                                                Hades
# 9                             Sensible World of Soccer
# 10                                Cafe Owner Simulator
# 11                                               Bingo
# 12                                    Spyro the Dragon
# 13                       Final Fantasy VIII Remastered
# 14                                   Tomb Raider: Gold
# 15                                        Scribble It!
# ...

# %% [markdown]
# ### fuzzymatcher

# %%
# fts4 in DDL
# >>> import os
# >>> import sys
# >>> os.path.dirname(sys.executable)

# %%
import fuzzymatcher

# %%
# cosine distance -> non pesa l'ordine
# levenshtein -> numero modifiche per passare da A a B
            # -> d(lev) >= |len(A)-len(B)|

# %%
matched_results = fuzzymatcher.fuzzy_left_join(match_df,
                                               steam_df,
                                              left_on='twitch_clean',
                                              right_on= 'steam_clean')

# %%
#solo 812 non ancora matchati

matched_results[matched_results['twitch_clean'] != ''][['best_match_score','twitch_clean','steam_clean','steam_name_right']].sort_values(by=['best_match_score'], ascending=False)

# %%
matched_results.loc[6836]
#cambia tutte le volte che rirunno

# %%
matched_results.twitch_clean.loc[6836] == matched_results.steam_clean.loc[6836]

# %% [markdown]
# match perfetto ma 0.28 best_match_score!!!

# %%
#match_df['steam_clean'] = ''

# j=0
# for elem in matched_results.twitch_clean:
#     if elem == '':
#         pass
#     else:
#         match_df.steam_clean[j] = matched_results.steam_clean
#         match_df.[j]
#     j+=1

# %% [markdown]
# capire come convertire best_match_score in percentuale  -> non si può schifo di documentazione

# %% [markdown]
# ## passo a fuzzywuzzy process

# %%
# pip install fuzzywuzzy
from fuzzywuzzy import process

# %%
def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=2):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].tolist()
    
    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m
    
    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2
    
    return df_1

# %%
fuzzy_merge(match_df, steam_df, 'twitch_clean', 'steam_clean', threshold=80)
